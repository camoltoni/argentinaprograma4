# %% [markdown]
# <a href="https://colab.research.google.com/github/camoltoni/argentinaprograma4/blob/main/u3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas_profiling

# %%
import pandas as pd
import numpy as np

#import dataframes

penguin_df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv')

# %%
penguin_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
penguin_df.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
penguin_df.axes
# Out:
# [RangeIndex(start=0, stop=344, step=1),
#  Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#         'flipper_length_mm', 'body_mass_g', 'sex'],
#        dtype='object')]

# %%
penguin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
penguin_df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
penguin_df.tail()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE

# %%
penguin_df.sample(5)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 23      Adelie     Biscoe            38.2           18.1              185.0
# 178  Chinstrap      Dream            50.5           18.4              200.0
# 96      Adelie      Dream            38.1           18.6              190.0
# 167  Chinstrap      Dream            50.5           19.6              201.0
# 16      Adelie  Torgersen            38.7           19.0              195.0
#
#      body_mass_g     sex
# 23        3950.0    MALE
# 178       3400.0  FEMALE
# 96        3700.0  FEMALE
# 167       4050.0    MALE
# 16        3450.0  FEMALE

# %%
penguin_df.mean()
# Out:
# <ipython-input-16-76514867aed7>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   penguin_df.mean()
# bill_length_mm         43.921930
# bill_depth_mm          17.151170
# flipper_length_mm     200.915205
# body_mass_g          4201.754386
# dtype: float64

# %%
penguin_df.groupby(['species','sex']).mean()
# Out:
# <ipython-input-20-b932806c71c5>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   penguin_df.groupby(['species','sex']).mean()
#                   bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species   sex
# Adelie    FEMALE       37.257534      17.621918         187.794521
#           MALE         40.390411      19.072603         192.410959
# Chinstrap FEMALE       46.573529      17.588235         191.735294
#           MALE         51.094118      19.252941         199.911765
# Gentoo    FEMALE       45.563793      14.237931         212.706897
#           MALE         49.473770      15.718033         221.540984
#
#                   body_mass_g
# species   sex
# Adelie    FEMALE  3368.835616
#           MALE    4043.493151
# Chinstrap FEMALE  3527.205882
# ...

# %%
penguin_df.mode()
# Out:
#   species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Biscoe            41.1           17.0              190.0
#
#    body_mass_g   sex
# 0       3800.0  MALE

# %%
penguin_df.max()
# Out:
# <ipython-input-22-a9bf8eba4eed>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   penguin_df.max()
# species                 Gentoo
# island               Torgersen
# bill_length_mm            59.6
# bill_depth_mm             21.5
# flipper_length_mm        231.0
# body_mass_g             6300.0
# dtype: object

# %%
penguin_df.min()
# Out:
# <ipython-input-23-be91e04df53d>:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   penguin_df.min()
# species              Adelie
# island               Biscoe
# bill_length_mm         32.1
# bill_depth_mm          13.1
# flipper_length_mm     172.0
# body_mass_g          2700.0
# dtype: object

# %%
penguin_df[['bill_length_mm', 'bill_depth_mm',
       'flipper_length_mm', 'body_mass_g']].pct_change(12)
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0               NaN            NaN                NaN          NaN
# 1               NaN            NaN                NaN          NaN
# 2               NaN            NaN                NaN          NaN
# 3               NaN            NaN                NaN          NaN
# 4               NaN            NaN                NaN          NaN
# ..              ...            ...                ...          ...
# 339       -0.116105      -0.132911          -0.022831    -0.104545
# 340        0.080831       0.021429           0.033654     0.060109
# 341        0.047817       0.039735           0.062201     0.045455
# 342       -0.104950      -0.026316          -0.018519     0.040000
# 343        0.002008       0.012579          -0.069869    -0.092437
#
# [344 rows x 4 columns]

# %%
penguin_df.dtypes.index
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
penguin_df.std()
# Out:
# <ipython-input-29-b7f269780c29>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   penguin_df.std()
# bill_length_mm         5.459584
# bill_depth_mm          1.974793
# flipper_length_mm     14.061714
# body_mass_g          801.954536
# dtype: float64

# %%
penguin_df.var()
# Out:
# <ipython-input-30-1d3379dd1b0f>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   penguin_df.var()
# bill_length_mm           29.807054
# bill_depth_mm             3.899808
# flipper_length_mm       197.731792
# body_mass_g          643131.077327
# dtype: float64

# %%
penguin_df.kurt()
# Out:
# <ipython-input-31-cffea2c045ee>:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   penguin_df.kurt()
# bill_length_mm      -0.876027
# bill_depth_mm       -0.906866
# flipper_length_mm   -0.984273
# body_mass_g         -0.719222
# dtype: float64

# %%
penguin_df.skew()
# Out:
# <ipython-input-32-56036d9827eb>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   penguin_df.skew()
# bill_length_mm       0.053118
# bill_depth_mm       -0.143465
# flipper_length_mm    0.345682
# body_mass_g          0.470329
# dtype: float64

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(penguin_df, title="Report")
profile
# Out:
# <ipython-input-33-8b1650a0d4f6>:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-08-31 22:00:43.441331&quot;&gt;&lt;title&gt;Report&lt;/title&gt;&lt;style&gt;
# /*!
# ...

# %% [markdown]
# Practiquemos juntos

# %%
anscombe_df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/anscombe.csv')

# %%
anscombe_1 = anscombe_df[anscombe_df.dataset == 'I'][['x', 'y']].copy()
anscombe_2 = anscombe_df[anscombe_df.dataset == 'II'][['x', 'y']].copy()
anscombe_3 = anscombe_df[anscombe_df.dataset == 'III'][['x', 'y']].copy()
anscombe_4 = anscombe_df[anscombe_df.dataset == 'IV'][['x', 'y']].copy()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# evalue para cada dataset tipos de variables,media, mediana, varianza y desv std.

# %%
#ejemplo primeros registros
print("DF I")
print(anscombe_1.std())
print("DF II")
print(anscombe_2.std())
print("DF III")
print(anscombe_3.std())
print("DF IV")
print(anscombe_4.std())
# Out:
# DF I
# x    3.316625
# y    2.031568
# dtype: float64
# DF II
# x    3.316625
# y    2.031657
# dtype: float64
# DF III
# x    3.316625
# y    2.030424
# dtype: float64
# DF IV
# x    3.316625
# y    2.030579
# dtype: float64

# %%
print("DF I")
print(anscombe_1.mean())
print("DF II")
print(anscombe_2.mean())
print("DF III")
print(anscombe_3.mean())
print("DF IV")
print(anscombe_4.mean())

# %%
penguin_df.fillna('mean)
