# %% [markdown]
# <a href="https://colab.research.google.com/github/camoltoni/argentinaprograma4/blob/main/notebooks/intro_ia_programacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Introducción al entorno práctico y ejemplos de primicias 📊
# ---

# %% [markdown]
# # Google Colab

# %% [markdown]
# ## ¿Qué es?

# %% [markdown]
# Google Colab es una herramienta gratuita que permite a los usuarios ejecutar código de Python en línea, sin necesidad de instalar ningún software en sus computadoras locales. Colab ofrece acceso a recursos de computación potentes, como GPUs y TPUs, lo que lo convierte en una excelente opción para experimentar con ciencia de datos y aprendizaje automático.
#
# Colab también ofrece un entorno de desarrollo integrado (IDE) en la nube, lo que facilita la escritura y ejecución de código, así como el colaboración en proyectos de ciencia de datos con otras personas. Los usuarios pueden guardar y compartir sus notebooks de Colab, lo que los convierte en una excelente forma de documentar y compartir el proceso de análisis de datos.

# %% [markdown]
# ## ¿Y si quiero usar mi computadora?

# %% [markdown]
# Si estás empezando, realmente no querés saber cómo es en tu computadora.
#
# Hay muchos tutoriales para esto, recomiendo que veas alguno. Yo te dejo igual unos tips:
#
# 1. Descargar Python. Esto depende tu sistema operativo.
# 2. Descargar una IDE (Visual Studio, Pycharm, etc).
# 3. Aprender a usar la consola mínimamente. Sirve para crear **entornos virtuales** que son importantes para los proyectos en Python.
# 4. Hacer `pip install ipykernel` para ejecutar las notebooks (este formato en donde podemos mezclar texto y código) de forma local.
# 5. Instalar las demás dependencias.
#
# Y ni te cuento si querés usar la GPU de tu computadora.

# %% [markdown]
# ## ¿Cómo usar Colab?
#
# Es muy fácil. Conviene crearse una carpeta en Google Drive (todos hemos usado alguna vez Google Drive). En esa carpeta, click derecho y buscar la opción de Google Colaboratory (ver imagen).
#
# También se puede entrar en https://colab.research.google.com/?hl=es y aparece la opción para que crees un Google Colab. Además, tiene varios ejemplos y te muestra cómo usar ciertas cosas.
#
# Una vez que hayas creado tu notebook de Colab, podés guardarlo y compartirlo con otros usuarios de Google Colab, así como yo a ustedes les comparto esto.
#
# No es nada más ni nada menos que eso, muy sencillo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Fundamentos en Python

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# En este caso, vamos a ver algoritmos en el lenguaje de programación Python.
#
# Veremos las instrucciones primitivas y algunos tipos de datos.

# %% [markdown]
# ## Variables y asignación

# %%
sueldo_hoy = 200000

# %% [markdown]
# Podemos revisar el valor de la variable (el espacio de memoria) de `sueldo_hoy` en la sección de variables de Google Colab.
#
# También podemos usar la función `print` que nos devuelve un mensaje por pantalla.

# %%
print(sueldo_hoy)
# Out:
# 200000

# %%
print(10)
# Out:
# 10

# %%
print("El sueldo de hoy es de", sueldo_hoy, "pesos.")
# Out:
# El sueldo de hoy es de 200000 pesos.

# %%
# strings se identifican con ""

# %% [markdown]
# ¿Qué tipo de dato es `sueldo_hoy`?

# %%
type(sueldo_hoy)
# Out:
# int

# %%
type(200000.20)
# Out:
# float

# %% [markdown]
# ¿Si hacemos un ajuste del sueldo?
#
# Operaciones sencillas.

# %%
sueldo_actualizado = sueldo_hoy * 1.2

print("Sueldo actualizado es de", sueldo_actualizado)
# Out:
# Sueldo actualizado es de 240000.0

# %%
type(sueldo_actualizado)
# Out:
# float

# %%
print(sueldo_actualizado)
# Out:
# 240000.0

# %% [markdown]
# ## Tres funciones sencillas para comenzar

# %% [markdown]
# Las funciones son las subrutinas que mencionaba Gerardo.
#
# Yo puedo utilizar algoritmos ya programados para que se ejecuten dentro del programa que estoy creando.
#
# Hay tres funciones fundamentales en Python:
# - `print`: muestra por pantalla sus argumentos en un solo mensaje.
# - `type`: devuelve el tipo de dato de su argumento.
# - `input`: permite el ingreso de un string a través del teclado hacia dentro del programa.

# %% [markdown]
# ### Función input

# %%
ingresado = input("Ingrese lo que quiera: ")

print("El usuario ingresó:", ingresado)

print("El tipo de dato es:", type(ingresado))
# Out:
# Ingrese lo que quiera: 12
# El usuario ingresó: 12
# El tipo de dato es: <class 'str'>

# %%
# Se puede forzar que se convierta a un número entero la entrada

ingresado = int(input("Ingrese lo que quiera: ")) # comentario

print("El usuario ingresó:", ingresado)

print("El tipo de dato es:", type(ingresado))
# Out:
# Ingrese lo que quiera: 10
# El usuario ingresó: 10
# El tipo de dato es: <class 'int'>

# %% [markdown]
# ### Importancia de los tipos (pequeño ejemplo)
#
# Los tipos de datos tienen sus particularidades. Por ejemplo, el tipo de dato `bool` es un tipo de dato de únicamente dos posibles valores: `True` o `False`.
#
# El tipo de dato `int` es para números enteros. El `float` es para los números con coma.
#
# El tipo de dato `str` (string) es un tipo de dato que refiere a una cadena de caracteres.
#
# Veamos qué pasa si quiero sumar números que en realidad son del tipo `str` en vez de `int`.

# %%
# sumemos dos enteros

2 + 3
# Out:
# 5

# %%
# los str se distinguen en la sintaxis de Python porque se usan
# con comillas (dobles o simples)

"2" + "3"
# Out:
# '23'

# %%
"abc" + "b" + ""
# Out:
# 'abcb'

# %%
# Ejemplos de tipos de datos

var_1 = 44                              # int
var_2 = 5.9                             # float
var_3 = "matias nicolas"                # str (string: cadena de caracteres)
var_4 = True                            # bool
var_5 = ["matias", "sosa", 25, var_2]   # list

# %%
print(var_5)
# Out:
# ['matias', 'sosa', 25, 5.9]

# %%
var_5[1]
# Out:
# 'sosa'

# %%
2 + 3 # aritmético
# Out:
# 5

# %%
2 < 3 # lógico
# Out:
# True

# %%
# operaciones (de comparación) que resultan en un valor booleano
print(var_1 > 10)
print(var_1 == 44)
print(var_1 <= 10)
# Out:
# True
# True
# False

# %% [markdown]
# ## Decisión

# %% [markdown]
# Vamos a hacer un programa según el pseudocódigo de Gerardo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# En Python, la decisión se hace con la palabra reservada if
sueldo = int(input("Ingrese su salario mensual: "))

if sueldo < 200000:
  print("Se debe aplicar un subsidio")
  print("Suerte!")

print("Fin del programa")
# Out:
# Ingrese su salario mensual: 50000
# Se debe aplicar un subsidio
# Suerte!
# Fin del programa

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sueldo = int(input("Ingrese su salario mensual: "))

if sueldo < 200000:
  if sueldo < 100000:
    print("Se debe aplicar subsidio completo")
  else:
    print("Se debe aplicar subsidio parcial")
# Out:
# Ingrese su salario mensual: 80000
# Se debe aplicar subsidio completo

# %% [markdown]
# Se podría incluso repensar la lógica y hacer dos preguntas:
#
# 1. Si el sueldo es menor a 100mil, aplicar subsidio completo.
# 2. Si no, ¿el sueldo es menor a 200mil? Si sí, aplicar subsidio parcial.
# 3. Si no, no hacer nada.

# %%
sueldo = int(input("Ingrese su salario mensual: "))

if sueldo < 100000:
  print("Se debe aplicar subsidio completo")
elif sueldo < 200000:
  print("Se debe aplicar subsidio parcial")
elif sueldo < 500000:
  print("Aplicar impuestos X")
else:
  print("Gana demasiado")


print("FIN DEL PROGRAMA")
# Out:
# Ingrese su salario mensual: 400000
# Aplicar impuestos X
# FIN DEL PROGRAMA

# %% [markdown]
# ## Iteración

# %%
# iteración con while

# sumar todos los valores que ingrese el usuario por teclado.
# el ingreso se finalizará cuando el número sea negativo

# mostrar la suma total

num_ingresado = int(input("Ingrese número a sumar: "))
suma = 0

while num_ingresado >= 0: # mientras sea positivo el num ingresado
  suma = suma + num_ingresado
  num_ingresado = int(input("Ingrese número a sumar: "))

print("La suma total es de", suma)
# Out:
# Ingrese número a sumar: 2
# Ingrese número a sumar: 4
# Ingrese número a sumar: 6
# Ingrese número a sumar: -10
# La suma total es de 12

# %%
# sumar valores de una lista

lista_de_valores = [1, 3, 2, 1]
suma = 0

for valor in lista_de_valores:
  suma += valor # equivale a suma = suma + valor

print("La suma total es de", suma)
# Out:
# La suma total es de 7
