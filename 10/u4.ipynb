# %% [markdown]
# <a href="https://colab.research.google.com/github/camoltoni/argentinaprograma4/blob/main/10/u4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import datetime
import random

# %%
random.seed(1)
dates = pd.date_range("20130101", periods=20)
df = pd.DataFrame(np.random.randn(20, 4,), index=dates, columns=list("ABCD"))

df
# Out:
#                    A         B         C         D
# 2013-01-01  0.983918 -1.505939 -0.271713  0.194463
# 2013-01-02  1.290150 -0.065405 -0.011612 -2.375066
# 2013-01-03 -1.205467  0.094939  0.720844  0.708463
# 2013-01-04  1.811244  0.262400  0.606269 -0.510702
# 2013-01-05  0.092799  0.939705 -0.153379  0.223441
# 2013-01-06 -0.701572  1.469087 -1.164466  0.998325
# 2013-01-07  0.683308 -0.092957 -0.945730  0.392325
# 2013-01-08  0.152738  0.454143  0.218079  0.712304
# 2013-01-09 -0.695203  0.666683  0.740228 -1.553590
# 2013-01-10 -1.384021 -0.568689  1.470802 -0.213712
# 2013-01-11 -0.385072 -0.386047  1.558729  0.265377
# 2013-01-12 -1.423186  0.658424 -0.870655 -0.121529
# 2013-01-13  0.951002 -1.047342 -1.079524 -0.983734
# 2013-01-14  2.938647  1.232298 -0.000351  1.199157
# 2013-01-15 -1.443423  0.597034 -3.003075  0.399019
# 2013-01-16  0.483624 -0.338875  0.723749  0.134399
# 2013-01-17 -1.038559 -1.189499 -1.727197  0.022706
# ...

# %% [markdown]
# 1. Seleccione las columnas A y B, y muestre todos sus valores en orden inverso

# %%
df[['A','B']]
# Out:
#                    A         B
# 2013-01-01  0.209965  0.302061
# 2013-01-02 -0.753566 -0.506319
# 2013-01-03  0.483380  0.507100
# 2013-01-04 -2.032697 -1.650409
# 2013-01-05  0.922236  1.170628
# 2013-01-06  0.491666 -0.174977
# 2013-01-07 -0.240981  1.425942
# 2013-01-08 -0.982319  0.441463
# 2013-01-09 -2.123755 -0.432824
# 2013-01-10 -1.325928 -0.265390
# 2013-01-11 -0.789787 -1.060104
# 2013-01-12 -1.759938 -2.163748
# 2013-01-13  1.647270  0.684496
# 2013-01-14 -1.239373 -2.923127
# 2013-01-15 -1.566051  0.524805
# 2013-01-16 -0.627513  1.001450
# 2013-01-17  0.570104 -0.526367
# 2013-01-18  0.517734 -1.030027
# 2013-01-19 -0.774741  0.584213
# 2013-01-20  1.384304 -0.164079

# %%
df.loc[::-1,['A','B']]
# Out:
#                    A         B
# 2013-01-20  1.384304 -0.164079
# 2013-01-19 -0.774741  0.584213
# 2013-01-18  0.517734 -1.030027
# 2013-01-17  0.570104 -0.526367
# 2013-01-16 -0.627513  1.001450
# 2013-01-15 -1.566051  0.524805
# 2013-01-14 -1.239373 -2.923127
# 2013-01-13  1.647270  0.684496
# 2013-01-12 -1.759938 -2.163748
# 2013-01-11 -0.789787 -1.060104
# 2013-01-10 -1.325928 -0.265390
# 2013-01-09 -2.123755 -0.432824
# 2013-01-08 -0.982319  0.441463
# 2013-01-07 -0.240981  1.425942
# 2013-01-06  0.491666 -0.174977
# 2013-01-05  0.922236  1.170628
# 2013-01-04 -2.032697 -1.650409
# 2013-01-03  0.483380  0.507100
# 2013-01-02 -0.753566 -0.506319
# 2013-01-01  0.209965  0.302061

# %%
prueba=df.melt(id_vars=['A','B'])
prueba.head(5).shift()
# Out:
#           A         B variable     value
# 0       NaN       NaN     None       NaN
# 1  0.209965  0.302061        C  0.008400
# 2 -0.753566 -0.506319        C  0.120982
# 3  0.483380  0.507100        C -0.708425
# 4 -2.032697 -1.650409        C  1.270243

# %% [markdown]
# 2. Seleccione todos los valores del DF tal que A > 1

# %%
mask = df['A']>1
df[mask]
# Out:
#                    A         B         C         D
# 2013-01-13  1.647270  0.684496  1.887481 -0.442121
# 2013-01-20  1.384304 -0.164079 -0.489616 -0.674510

# %%
# Out:
#                    A         B         C         D
# 2013-01-01       NaN       NaN       NaN       NaN
# 2013-01-02       NaN       NaN       NaN       NaN
# 2013-01-03       NaN       NaN       NaN       NaN
# 2013-01-04       NaN       NaN       NaN       NaN
# 2013-01-05       NaN       NaN       NaN       NaN
# 2013-01-06       NaN       NaN       NaN       NaN
# 2013-01-07       NaN       NaN       NaN       NaN
# 2013-01-08       NaN       NaN       NaN       NaN
# 2013-01-09       NaN       NaN       NaN       NaN
# 2013-01-10       NaN       NaN       NaN       NaN
# 2013-01-11       NaN       NaN       NaN       NaN
# 2013-01-12       NaN       NaN       NaN       NaN
# 2013-01-13  1.647270  0.684496  1.887481 -0.442121
# 2013-01-14       NaN       NaN       NaN       NaN
# 2013-01-15       NaN       NaN       NaN       NaN
# 2013-01-16       NaN       NaN       NaN       NaN
# 2013-01-17       NaN       NaN       NaN       NaN
# ...

# %% [markdown]
# 3. genere una lambda expression para resumir los datos por la mediana + 1. Es decir f(x)= mediana(x)+1

# %%
df.agg(lambda x: np.median(x) + 1)
# Out:
# A    0.309460
# B    0.830472
# C    1.144189
# D    0.592432
# dtype: float64

# %% [markdown]
# 4. Transforme los datos de df elevandolos al cubo. Es decir f(x) = x^3

# %%
df.transform(lambda x: x**3)
# Out:
#                    A          B             C         D
# 2013-01-01  0.009256   0.027560  5.927066e-07  0.000681
# 2013-01-02 -0.427921  -0.129800  1.770768e-03  0.010631
# 2013-01-03  0.112945   0.130401 -3.555338e-01 -8.763229
# 2013-01-04 -8.398819  -4.495465  2.049558e+00 -2.877171
# 2013-01-05  0.784380   1.604192  1.269080e+00 -0.051901
# 2013-01-06  0.118853  -0.005357  3.599288e-01 -0.689122
# 2013-01-07 -0.013994   2.899381  1.217075e-03  0.276149
# 2013-01-08 -0.947889   0.086036  1.524208e-01  2.150043
# 2013-01-09 -9.578848  -0.081084  3.047395e-02 -0.000016
# 2013-01-10 -2.331093  -0.018692 -2.484783e-01 -0.574438
# 2013-01-11 -0.492640  -1.191367  7.891760e-03  0.045076
# 2013-01-12 -5.451203 -10.130253 -5.370195e+00 -0.283374
# 2013-01-13  4.469863   0.320710  6.724305e+00 -0.086422
# 2013-01-14 -1.903734 -24.977164  3.012667e-05 -0.113569
# 2013-01-15 -3.840765   0.144542 -2.448326e+00  0.315522
# 2013-01-16 -0.247098   1.004355  1.544814e+00 -0.123659
# ...

# %%
df1 = pd.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    },
    index=[0, 1, 2, 3],
)


df2 = pd.DataFrame(
    {
        "A": ["A4", "A5", "A6", "A7"],
        "B": ["B4", "B5", "B6", "B7"],
        "C": ["C4", "C5", "C6", "C7"],
        "D": ["D4", "D5", "D6", "D7"],
    },
    index=[4, 5, 6, 7],
)


df3 = pd.DataFrame(
    {
        "A": ["A8", "A9", "A10", "A11"],
        "B": ["B8", "B9", "B10", "B11"],
        "C": ["C8", "C9", "C10", "C11"],
        "D": ["D8", "D9", "D10", "D11"],
    },
    index=[8, 9, 10, 11],
)

# %% [markdown]
# 5. concatene df1, df2, df3 y asignelo a df4

# %%
df4= pd.concat([df1, df2, df3])
df4
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# 6. Arme deciles con df['A'] y asignelos a una nueva serie de df

# %%
df['deciles'] = pd.qcut(df['A'], 10)

# %%
df
# Out:
#                    A         B         C         D           deciles
# 2013-01-01  0.983918 -1.505939 -0.271713  0.194463    (0.764, 1.045]
# 2013-01-02  1.290150 -0.065405 -0.011612 -2.375066    (1.045, 1.888]
# 2013-01-03 -1.205467  0.094939  0.720844  0.708463  (-1.388, -1.072]
# 2013-01-04  1.811244  0.262400  0.606269 -0.510702    (1.045, 1.888]
# 2013-01-05  0.092799  0.939705 -0.153379  0.223441   (-0.202, 0.123]
# 2013-01-06 -0.701572  1.469087 -1.164466  0.998325  (-1.072, -0.697]
# 2013-01-07  0.683308 -0.092957 -0.945730  0.392325    (0.498, 0.764]
# 2013-01-08  0.152738  0.454143  0.218079  0.712304    (0.123, 0.498]
# 2013-01-09 -0.695203  0.666683  0.740228 -1.553590  (-0.697, -0.202]
# 2013-01-10 -1.384021 -0.568689  1.470802 -0.213712  (-1.388, -1.072]
# 2013-01-11 -0.385072 -0.386047  1.558729  0.265377  (-0.697, -0.202]
# 2013-01-12 -1.423186  0.658424 -0.870655 -0.121529  (-1.444, -1.388]
# 2013-01-13  0.951002 -1.047342 -1.079524 -0.983734    (0.764, 1.045]
# ...

# %%
speeds = pd.DataFrame(
    [
        ("bird", "Falconiformes", 389.0),
        ("bird", "Psittaciformes", 24.0),
        ("mammal", "Carnivora", 80.2),
        ("mammal", "Primates", np.nan),
        ("mammal", "Carnivora", 58),
    ],
    index=["falcon", "parrot", "lion", "monkey", "leopard"],
    columns=("class", "order", "max_speed"),
)

# %% [markdown]
# 7. Agrupe speeds por clase y estime la max velocidad para cada clase

# %%
speeds.groupby('class').agg('max')
# Out:
#                  order  max_speed
# class
# bird    Psittaciformes      389.0
# mammal        Primates       80.2

# %%
n = 100

weight = np.random.normal(75, 20, size=n)

height = np.random.normal(170, 10, size=n)

time = pd.date_range("1/1/2000", periods=n)

gender = np.random.choice(["male", "female"], size=n)

df = pd.DataFrame(
    {"height": height, "weight": weight, "gender": gender}, index=time
)

# %% [markdown]
# 8. estime el peso y altura promedio y mediano por sexo

# %%
df.groupby('gender').agg(['mean', 'median'])
# Out:
#             height                 weight
#               mean      median       mean     median
# gender
# female  170.663197  171.470156  71.372798  70.575917
# male    169.343228  171.000905  76.078821  75.595118

# %%
left = pd.DataFrame(
    {
        "key": ["K0", "K1", "K2", "K3"],
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
    }
)


right = pd.DataFrame(
    {
        "key": ["K0", "K1", "K2", "K3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    }
)

# %% [markdown]
# 9. realice y compare un Left join, Right join e Inner Join

# %%
pd.merge(left, right, how = 'left', on= 'key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
pd.merge(left, right, how = 'right', on= 'key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
pd.merge(left, right, how = 'inner', on= 'key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3
